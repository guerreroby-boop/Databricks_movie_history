# %% [markdown]
# ### Introducción a Notebooks
# #### Interfáz Gráfica
# #### Comandos Mágicos
# - %python
# - %sql
# - %scala
# - %r

# %% [markdown]
# #### Comando Mágico %python

# %%
message = 'Hola mundo'

# %%
print(message)

# %%
message = 'hello world'
display(message)

# %% [markdown]
# #### Comando Mágico %sql

# %%
# %sql
SELECT "Hola"

# %% [markdown]
# #### Comando Mágico %r

# %%
# %r
print("Hola Mundo")

# %% [markdown]
# #### Comando Mágico %fs

# %%
# %fs
ls

# %% [markdown]
# #### Comando Mágico %sh

# %%
# %sh
ps

# %% [markdown]
# #### Comando Mágico %lsmagic

# %%
lsmagic

# %%
# %env?
