# %% [markdown]
# #### Acceso al DataFrame mendiante SQL

# %% [markdown]
# ###Local Temporal View
# 1. Crear vista(view) temporal en la base de datos
# 2. Acceder a la vista(view) desde la celda SQL
# 3. Acceder a la vista(view) desde la celda PYTHON
# 4. Acceder a la vista(view) desde otro notebook

# %%
# %run "../includes/configurations"

# %%
result_movie_genre_language_df = spark.read.parquet(f"{gold_folder_path}/results_movies_genre_language")

# %%
result_movie_genre_language_df.createOrReplaceTempView("v_movie_genre_langague")

# %%
# %sql
SELECT * 
FROM v_movie_genre_langague
WHERE vote_average > 7.5

# %%
result_movie_language1 = spark.sql("select * from v_movie_genre_langague where vote_average >7.5")
result_movie_language1.show()

# %% [markdown]
# ###Local Global View
# 1. Crear vista(view) global en la base de datos
# 2. Acceder a la vista(view) desde la celsa SQL
# 3. Acceder a la vista(view) desde la celsa PYTHON
# 4. Acceder a la vista(view) desde otro notebook

# %%
result_movie_genre_language_df.createOrReplaceGlobalTempView("gv_movie_genre_langague")

# %%
# %sql
SHOW TABLES IN global_temp;

# %%
# %sql
SELECT *
FROM global_temp.gv_movie_genre_langague

# %%
spark.sql("select * from global_temp.gv_movie_genre_langague").display()
