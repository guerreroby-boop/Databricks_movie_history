# %%
# %run "../includes/configurations"

# %%
movies_df = spark.read.parquet(f"{silver_folder_path}/movies")

# %%
movies_filtered_df = movies_df.filter("year_release_date = 2007")

# %%
movies_filtered_df = movies_df.filter(movies_df.year_release_date == 2008)

# %%
movies_filtered_df = movies_df.filter(movies_df["year_release_date"] == 2009)

# %%
movies_filtered_df = movies_df.filter("year_release_date = 2007 and vote_average > 7")

# %%
movies_filtered_df = movies_df.filter((movies_df.year_release_date == 2008) & (movies_df.vote_average>7))

# %%
movies_filtered_df = movies_df.where((movies_df.year_release_date == 2008) & (movies_df.vote_average>7))

# %%
display(movies_filtered_df)
