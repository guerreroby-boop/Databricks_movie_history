-- %% [markdown]
-- ####Creación de Base de Datos

-- %% [markdown]
-- 1. Documentación sobre Spark Sql
-- 2. Crear la base de datos **"demo"**
-- 3. Acceder al **"Catalog"** en la **"Interfaz de Usuario"**
-- 4. Comando **"SHOW"**
-- 5. Comando **DESCRIBE(DESC)**
-- 6. Mostrar la Base de Datos actual

-- %%
CREATE SCHEMA IF NOT EXISTS demo;

-- %%
SHOW DATABASES;

-- %%
DESCRIBE DATABASE demo;

-- %%
DESCRIBE DATABASE EXTENDED demo;

-- %%
SELECT current_database();

-- %%
SHOW TABLES;

-- %%
SHOW TABLES IN demo;

-- %%
USE demo;

-- %%
SELECT current_database();

-- %%
SHOW TABLES IN default;

-- %% [markdown]
-- ####Tablas Administradas (Managed Tables)

-- %% [markdown]
-- ###Objetivos
-- 1. Crear una **"Tabla administrada (Managed Table)"** con Python
-- 2. Crear una **"Tabla administrada (Managed Table)"** con SQL
-- 3. Efecto de eliminar una tabla administrada
-- 4. Describir (Describe) la tabla

-- %%
%run "../includes/configurations"

-- %%
%python
result_movie_genre_language = spark.read.parquet(f"{gold_folder_path}/results_movies_genre_language")

-- %%
%python
result_movie_genre_language.write.format("delta").mode("overwrite").saveAsTable("demo.result_movie_genre_language_python")

-- %%
USE demo;
SHOW TABLES;

-- %%
DESCRIBE EXTENDED result_movie_genre_language_python;

-- %%
CREATE TABLE demo.result_movie_genre_language_sql
AS
SELECT *
FROM result_movie_genre_language
WHERE genre_name = 'Adventure';

-- %%
SELECT *
FROM result_movie_genre_language_sql;

-- %%
SELECT current_database();

-- %%
DESCRIBE EXTENDED result_movie_genre_language_sql;

-- %%
DROP TABLE result_movie_genre_language_sql;

-- %%
SHOW TABLES IN demo;

-- %% [markdown]
-- #### Tablas externas

-- %% [markdown]
-- ###Objetivos
-- 1. Crear una tabla externa con python
-- 2. Crear una tabla externa con sql
-- 3. Efecto de eliminación de una tabla externa
-- 4. Describir la tabla

-- %%
%python
result_movie_genre_language.write.format("delta").option("path", f"{gold_folder_path}/result_movie_genre_language_py").saveAsTable("demo.result_movie_genre_language_py")

-- %%
DESC EXTENDED demo.result_movie_genre_language_py

-- %%
CREATE TABLE demo.result_movie_genre_language_sql(
  title STRING,
  duration_time INT,
  release_date DATE,
  vote_average DOUBLE,
  language_name STRING,
  genre_name STRING,
  created_date TIMESTAMP
)
USING PARQUET
LOCATION "abfss://gold@moviehistorybymg.dfs.core.windows.net/result_movie_genre_language_ext_sql"

-- %% [markdown]
-- #### Vistas (Views)

-- %% [markdown]
-- ### Objetivos
-- 1. Crear Vista Temporal
-- 2. Crear Vista TEmporal Global
-- 3. Crear Vista Permanente

-- %%
SELECT current_database();

-- %%
CREATE OR REPLACE TEMP VIEW v_results_movies_genres_language
AS
SELECT *
FROM demo.result_movie_genre_language_py
WHERE genre_name = 'Adventure';

-- %%
SELECT *
FROM v_results_movies_genres_language;

-- %%
CREATE OR REPLACE GLOBAL TEMP VIEW gv_results_movies_genres_language
AS
SELECT *
FROM demo.result_movie_genre_language_py
WHERE genre_name = 'Drama';

-- %%
SHOW TABLES IN global_temp;

-- %%
SELECT *
FROM global_temp.gv_results_movies_genres_language;

-- %%
CREATE OR REPLACE VIEW pv_results_movies_genres_language
AS
SELECT *
FROM demo.result_movie_genre_language_py
WHERE genre_name = 'Comedy';

-- %%
SHOW TABLES;

-- %%
SELECT *
FROM pv_results_movies_genres_language;
