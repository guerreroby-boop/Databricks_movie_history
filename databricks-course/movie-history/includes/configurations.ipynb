# %%
bronze_folder_path = "abfss://bronze@moviehistorybymg.dfs.core.windows.net"
silver_folder_path = "abfss://silver@moviehistorybymg.dfs.core.windows.net"
gold_folder_path = "abfss://gold@moviehistorybymg.dfs.core.windows.net"
